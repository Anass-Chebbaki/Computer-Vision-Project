# %% [markdown]
# #**SCRIPT PER LA VERIFICA DELLE ANNOTAZONI**
#
# Tramite il seguente script si verifica se l'annotazione è stata effettuata correttamente dagli annotatori. Il formato dell'annotazioni è il seguente
#
# "class_id", "x_center", "y_center", "width height", "x1", "y1", "visibility"
#
# Un'esempio con **1 box** e un **1 keypoint** che rende l'idea:
#
# | class_id | x_center | y_center | width  | height | x_kp | y_kp | visibility|
# | ---------| -------- | ---------| -------| -------|------|------|-----------|
# | 0        | 0.2577   | 0.2751   | 0.1625 | 0.2088 |0.2715|0.2751| 2         |
#
# Dove:
#
# **v = 2 → visibile e annotato manualmente**
#
# **v = 1 → non visibile ma presente nella struttura (es. occluso)**
#
# **v = 0 → non presente o non annotabile (placeholder)**

# %% [markdown]
# ---

# %%
# === MOUNT DRIVE ===
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **VERSIONE 2.0 (CON LOG DINAMICO)**
#
# ⚠ Utilizzare questa versione di codice ⚠
#
# Questa versione consente di generare un file .csv contenente keypoints per bounded box con il seguente schema:
#
# | file\_name      | num\_kp\_box\_01 | num\_kp\_box\_02 | num\_kp\_box\_03 |
# | --------------- | ---------------- | ---------------- | ---------------- |
# | staffa\_001.jpg | 2                |                  |                  |
# | staffa\_002.jpg | 4                | 3                |                  |
# | staffa\_003.jpg | 5                | 5                | 4                |

# %% [markdown]
# ---

# %%
import os
import cv2
import csv

# === PERCORSI CARTELLE ===
images_dir = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_PCTO/Dataset_GoodAnnotated_PCTO_Agostino/images"
labels_dir = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_PCTO/Dataset_GoodAnnotated_PCTO_Agostino/labels"
output_dir = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_PCTO/Dataset_GoodAnnotated_PCTO_Agostino/output"
csv_log_path = os.path.join(output_dir, "numero_keypoints_log.csv")

# === PARAMETRI VISUALIZZAZIONE ===
bbox_color = (0, 255, 0)
kp_color = (0, 0, 255)
radius = 25
thickness = 20
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 3
text_thickness = 10
text_color = (0, 0, 255)

# === CREA CARTELLA DI OUTPUT ===
os.makedirs(output_dir, exist_ok=True)

# === FILTRA E PRENDI PRIME 5 IMMAGINI ===
file_list = sorted(os.listdir(images_dir))
file_list = [f for f in file_list if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
#file_list = file_list[:5]  # solo le prime 5 per test (COMMENTARLO SE SI VOGLIONO FARE TUTTE)

# === CSV LOG DINAMICO ===
csv_log = []
max_boxes = 0  # si utilizza x contare solo le colonne necessarie

for file_name in file_list:
    image_path = os.path.join(images_dir, file_name)
    label_path = os.path.join(labels_dir, os.path.splitext(file_name)[0] + '.txt')

    if not os.path.exists(label_path):
        print(f"⚠️ Nessuna label trovata per {file_name}")
        continue

    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ Errore nel leggere l'immagine: {image_path}")
        continue

    h, w = image.shape[:2]
    kp_counts = []  # keypoints per bounding box

    with open(label_path, 'r') as f:
        lines = f.readlines()

    index = 1
    for box_index, line in enumerate(lines):
        parts = line.strip().split()
        if len(parts) < 6:
            continue

        class_id = int(parts[0])
        x_center, y_center, bw, bh = map(float, parts[1:5])
        keypoints = list(map(float, parts[5:]))

        # Bounding box
        x1 = int((x_center - bw / 2) * w)
        y1 = int((y_center - bh / 2) * h)
        x2 = int((x_center + bw / 2) * w)
        y2 = int((y_center + bh / 2) * h)
        cv2.rectangle(image, (x1, y1), (x2, y2), bbox_color, thickness)

        # Keypoints per box
        count = 0

        for i in range(0, len(keypoints), 3):
            xk = int(keypoints[i] * w)
            yk = int(keypoints[i + 1] * h)
            v = int(keypoints[i + 2])

            if v > 0:
                cv2.circle(image, (xk, yk), radius, kp_color, -1)
                cv2.putText(image, str(index), (xk + 5, yk - 5), font, font_scale, text_color, text_thickness)
                count += 1
                index += 1

        kp_counts.append(count)

    # Salva immagine annotata
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, image)
    print(f"✅ Annotata e salvata: {file_name}")

    # Salva il conteggio nel log
    max_boxes = max(max_boxes, len(kp_counts))
    csv_log.append((file_name, *kp_counts))

# === CREAZIONE HEADER CSV ===
header = ["file_name"] + [f"num_kp_box_{i+1:02d}" for i in range(max_boxes)]

# === SCRIVI IL CSV ===
with open(csv_log_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(csv_log)

print(f"\n📄 CSV salvato con successo: {csv_log_path}")
print("✅ Tutte le immagini elaborate.")
# Out:
# ✅ Annotata e salvata: staffe_001.jpg
# ✅ Annotata e salvata: staffe_002.jpg
# ✅ Annotata e salvata: staffe_003.jpg
# ✅ Annotata e salvata: staffe_004.jpg
# ✅ Annotata e salvata: staffe_005.jpg
# ✅ Annotata e salvata: staffe_006.jpg
# ✅ Annotata e salvata: staffe_007.jpg
# ✅ Annotata e salvata: staffe_008.jpg
# ✅ Annotata e salvata: staffe_009.jpg
# ✅ Annotata e salvata: staffe_010.jpg
#
# 📄 CSV salvato con successo: /content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_PCTO/Dataset_GoodAnnotated_PCTO_Agostino/output/numero_keypoints_log.csv
# ✅ Tutte le immagini elaborate.

# %% [markdown]
# # **NUOVA VERSIONE CHE FA SORTING PER EVITARE ERRORI**

# %%
import os
import cv2
import csv

# === PERCORSI CARTELLE ===
images_dir = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_Nostri/Dataset_Clean_GoodAnnotation/images"
labels_dir = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_Nostri/Dataset_Clean_GoodAnnotation/labels"
output_dir = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_Nostri/Dataset_Clean_GoodAnnotation/output"
csv_log_path = os.path.join(output_dir, "numero_keypoints_log.csv")

# === PARAMETRI VISUALIZZAZIONE ===
bbox_color = (0, 255, 0)
kp_color = (0, 0, 255)
radius = 25
thickness = 20
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 3
text_thickness = 10
text_color = (0, 0, 255)

# === CREA CARTELLA DI OUTPUT ===
os.makedirs(output_dir, exist_ok=True)

# === ORDINA E ABBINA FILE ===
image_files = sorted([f for f in os.listdir(images_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
label_files = sorted([f for f in os.listdir(labels_dir) if f.lower().endswith('.txt')])

image_names = [os.path.splitext(f)[0] for f in image_files]
label_names = [os.path.splitext(f)[0] for f in label_files]

# Tieni solo i file che hanno sia immagine che label
matched_files = sorted(set(image_names) & set(label_names))
print(f"🔍 Trovati {len(matched_files)} file validi con immagine e label.")

# === CSV LOG DINAMICO ===
csv_log = []
max_boxes = 0  # per contare il massimo numero di colonne nel CSV

for base_name in matched_files:
    image_ext = next((ext for ext in ['.jpg', '.jpeg', '.png'] if os.path.exists(os.path.join(images_dir, base_name + ext))), None)
    if not image_ext:
        print(f"❌ Estensione immagine non trovata per {base_name}")
        continue

    image_path = os.path.join(images_dir, base_name + image_ext)
    label_path = os.path.join(labels_dir, base_name + '.txt')

    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ Errore nel leggere l'immagine: {image_path}")
        continue

    h, w = image.shape[:2]
    kp_counts = []

    with open(label_path, 'r') as f:
        lines = f.readlines()



    for box_index, line in enumerate(lines):
        parts = line.strip().split()
        if len(parts) < 6:
            continue

        class_id = int(parts[0])
        x_center, y_center, bw, bh = map(float, parts[1:5])
        keypoints = list(map(float, parts[5:]))

        # Bounding box
        x1 = int((x_center - bw / 2) * w)
        y1 = int((y_center - bh / 2) * h)
        x2 = int((x_center + bw / 2) * w)
        y2 = int((y_center + bh / 2) * h)
        cv2.rectangle(image, (x1, y1), (x2, y2), bbox_color, thickness)

        # Keypoints
        count = 0
        index = 1
        for i in range(0, len(keypoints), 3):
            xk = int(keypoints[i] * w)
            yk = int(keypoints[i + 1] * h)
            v = int(keypoints[i + 2])
            if v > 0:
                cv2.circle(image, (xk, yk), radius, kp_color, -1)
                cv2.putText(image, str(index), (xk + 5, yk - 5), font, font_scale, text_color, text_thickness)
                count += 1
                index += 1

        kp_counts.append(count)

    output_path = os.path.join(output_dir, base_name + image_ext)
    cv2.imwrite(output_path, image)
    print(f"✅ Annotata e salvata: {base_name + image_ext}")

    max_boxes = max(max_boxes, len(kp_counts))
    csv_log.append((base_name + image_ext, *kp_counts))

# === HEADER CSV ===
header = ["file_name"] + [f"num_kp_box_{i+1:02d}" for i in range(max_boxes)]

# === SALVA CSV ===
with open(csv_log_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(csv_log)

print(f"\n📄 CSV salvato con successo: {csv_log_path}")
print("✅ Tutte le immagini elaborate.")
# Out:
# 🔍 Trovati 257 file validi con immagine e label.
# ✅ Annotata e salvata: staffe_001.jpg
# ✅ Annotata e salvata: staffe_002.jpg
# ✅ Annotata e salvata: staffe_003.jpg
# ✅ Annotata e salvata: staffe_004.jpg
# ✅ Annotata e salvata: staffe_005.jpg
# ✅ Annotata e salvata: staffe_006.jpg
# ✅ Annotata e salvata: staffe_007.jpg
# ✅ Annotata e salvata: staffe_008.jpg
# ✅ Annotata e salvata: staffe_009.jpg
# ✅ Annotata e salvata: staffe_010.jpg
# ✅ Annotata e salvata: staffe_011.jpg
# ✅ Annotata e salvata: staffe_012.jpg
# ✅ Annotata e salvata: staffe_013.jpg
# ✅ Annotata e salvata: staffe_014.jpg
# ✅ Annotata e salvata: staffe_015.jpg
# ✅ Annotata e salvata: staffe_016.jpg
# ✅ Annotata e salvata: staffe_017.jpg
# ✅ Annotata e salvata: staffe_018.jpg
# ✅ Annotata e salvata: staffe_019.jpg
# ✅ Annotata e salvata: staffe_020.jpg
# ✅ Annotata e salvata: staffe_021.jpg
# ✅ Annotata e salvata: staffe_022.jpg
# ✅ Annotata e salvata: staffe_023.jpg
# ✅ Annotata e salvata: staffe_024.jpg
# ✅ Annotata e salvata: staffe_025.jpg
# ✅ Annotata e salvata: staffe_026.jpg
# ✅ Annotata e salvata: staffe_027.jpg
# ✅ Annotata e salvata: staffe_028.jpg
# ✅ Annotata e salvata: staffe_029.jpg
# ✅ Annotata e salvata: staffe_030.jpg
# ✅ Annotata e salvata: staffe_031.jpg
# ✅ Annotata e salvata: staffe_032.jpg
# ✅ Annotata e salvata: staffe_033.jpg
# ✅ Annotata e salvata: staffe_034.jpg
# ✅ Annotata e salvata: staffe_035.jpg
# ✅ Annotata e salvata: staffe_036.jpg
# ✅ Annotata e salvata: staffe_037.jpg
# ✅ Annotata e salvata: staffe_038.jpg
# ✅ Annotata e salvata: staffe_039.jpg
# ✅ Annotata e salvata: staffe_040.jpg
# ✅ Annotata e salvata: staffe_041.jpg
# ✅ Annotata e salvata: staffe_042.jpg
# ✅ Annotata e salvata: staffe_043.jpg
# ✅ Annotata e salvata: staffe_044.jpg
# ✅ Annotata e salvata: staffe_045.jpg
# ✅ Annotata e salvata: staffe_046.jpg
# ✅ Annotata e salvata: staffe_047.jpg
# ✅ Annotata e salvata: staffe_048.jpg
# ✅ Annotata e salvata: staffe_049.jpg
# ✅ Annotata e salvata: staffe_050.jpg
# ✅ Annotata e salvata: staffe_051.jpg
# ✅ Annotata e salvata: staffe_052.jpg
# ✅ Annotata e salvata: staffe_053.jpg
# ✅ Annotata e salvata: staffe_054.jpg
# ✅ Annotata e salvata: staffe_055.jpg
# ✅ Annotata e salvata: staffe_056.jpg
# ✅ Annotata e salvata: staffe_057.jpg
# ✅ Annotata e salvata: staffe_058.jpg
# ✅ Annotata e salvata: staffe_059.jpg
# ✅ Annotata e salvata: staffe_060.jpg
# ✅ Annotata e salvata: staffe_061.jpg
# ✅ Annotata e salvata: staffe_062.jpg
# ✅ Annotata e salvata: staffe_063.jpg
# ✅ Annotata e salvata: staffe_064.jpg
# ✅ Annotata e salvata: staffe_065.jpg
# ✅ Annotata e salvata: staffe_066.jpg
# ✅ Annotata e salvata: staffe_067.jpg
# ✅ Annotata e salvata: staffe_068.jpg
# ✅ Annotata e salvata: staffe_069.jpg
# ✅ Annotata e salvata: staffe_070.jpg
# ✅ Annotata e salvata: staffe_071.png
# ✅ Annotata e salvata: staffe_072.png
# ✅ Annotata e salvata: staffe_073.png
# ✅ Annotata e salvata: staffe_074.png
# ✅ Annotata e salvata: staffe_075.png
# ✅ Annotata e salvata: staffe_076.png
# ✅ Annotata e salvata: staffe_077.png
# ✅ Annotata e salvata: staffe_078.png
# ✅ Annotata e salvata: staffe_079.png
# ✅ Annotata e salvata: staffe_080.png
# ✅ Annotata e salvata: staffe_081.png
# ✅ Annotata e salvata: staffe_082.png
# ✅ Annotata e salvata: staffe_083.png
# ✅ Annotata e salvata: staffe_084.png
# ✅ Annotata e salvata: staffe_085.png
# ✅ Annotata e salvata: staffe_086.png
# ✅ Annotata e salvata: staffe_087.png
# ✅ Annotata e salvata: staffe_088.jpg
# ✅ Annotata e salvata: staffe_089.png
# ✅ Annotata e salvata: staffe_090.jpg
# ✅ Annotata e salvata: staffe_091.png
# ✅ Annotata e salvata: staffe_092.jpg
# ✅ Annotata e salvata: staffe_093.jpg
# ✅ Annotata e salvata: staffe_094.png
# ✅ Annotata e salvata: staffe_096.jpg
# ✅ Annotata e salvata: staffe_097.jpg
# ✅ Annotata e salvata: staffe_098.jpg
# ✅ Annotata e salvata: staffe_099.jpg
# ✅ Annotata e salvata: staffe_100.png
# ✅ Annotata e salvata: staffe_101.jpg
# ✅ Annotata e salvata: staffe_102.jpg
# ✅ Annotata e salvata: staffe_103.jpg
# ✅ Annotata e salvata: staffe_104.jpg
# ✅ Annotata e salvata: staffe_105.png
# ✅ Annotata e salvata: staffe_106.jpg
# ✅ Annotata e salvata: staffe_107.png
# ✅ Annotata e salvata: staffe_108.jpg
# ✅ Annotata e salvata: staffe_109.jpg
# ✅ Annotata e salvata: staffe_110.png
# ✅ Annotata e salvata: staffe_111.jpg
# ✅ Annotata e salvata: staffe_112.jpg
# ✅ Annotata e salvata: staffe_113.jpg
# ✅ Annotata e salvata: staffe_114.jpg
# ✅ Annotata e salvata: staffe_115.jpg
# ✅ Annotata e salvata: staffe_116.jpg
# ✅ Annotata e salvata: staffe_117.png
# ✅ Annotata e salvata: staffe_118.jpg
# ✅ Annotata e salvata: staffe_119.jpg
# ✅ Annotata e salvata: staffe_120.jpg
# ✅ Annotata e salvata: staffe_121.jpg
# ✅ Annotata e salvata: staffe_122.jpg
# ✅ Annotata e salvata: staffe_123.jpg
# ✅ Annotata e salvata: staffe_124.jpg
# ✅ Annotata e salvata: staffe_125.jpg
# ✅ Annotata e salvata: staffe_126.jpg
# ✅ Annotata e salvata: staffe_127.jpg
# ✅ Annotata e salvata: staffe_128.jpg
# ✅ Annotata e salvata: staffe_129.jpg
# ✅ Annotata e salvata: staffe_130.jpg
# ✅ Annotata e salvata: staffe_131.jpg
# ✅ Annotata e salvata: staffe_132.jpg
# ✅ Annotata e salvata: staffe_133.jpg
# ✅ Annotata e salvata: staffe_134.jpg
# ✅ Annotata e salvata: staffe_135.png
# ✅ Annotata e salvata: staffe_136.png
# ✅ Annotata e salvata: staffe_137.jpg
# ✅ Annotata e salvata: staffe_138.jpg
# ✅ Annotata e salvata: staffe_139.jpg
# ✅ Annotata e salvata: staffe_140.jpg
# ✅ Annotata e salvata: staffe_141.jpg
# ✅ Annotata e salvata: staffe_142.jpg
# ✅ Annotata e salvata: staffe_143.png
# ✅ Annotata e salvata: staffe_144.jpg
# ✅ Annotata e salvata: staffe_145.jpg
# ✅ Annotata e salvata: staffe_146.jpg
# ✅ Annotata e salvata: staffe_147.jpg
# ✅ Annotata e salvata: staffe_148.jpg
# ✅ Annotata e salvata: staffe_149.jpg
# ✅ Annotata e salvata: staffe_150.png
# ✅ Annotata e salvata: staffe_151.jpg
# ✅ Annotata e salvata: staffe_152.png
# ✅ Annotata e salvata: staffe_153.jpg
# ✅ Annotata e salvata: staffe_154.jpg
# ✅ Annotata e salvata: staffe_155.jpg
# ✅ Annotata e salvata: staffe_156.jpg
# ✅ Annotata e salvata: staffe_157.jpg
# ✅ Annotata e salvata: staffe_158.png
# ✅ Annotata e salvata: staffe_159.jpg
# ✅ Annotata e salvata: staffe_160.png
# ✅ Annotata e salvata: staffe_161.jpg
# ✅ Annotata e salvata: staffe_162.jpg
# ✅ Annotata e salvata: staffe_163.png
# ✅ Annotata e salvata: staffe_164.jpg
# ✅ Annotata e salvata: staffe_165.png
# ✅ Annotata e salvata: staffe_166.jpg
# ✅ Annotata e salvata: staffe_167.jpg
# ✅ Annotata e salvata: staffe_168.jpg
# ✅ Annotata e salvata: staffe_169.png
# ✅ Annotata e salvata: staffe_170.jpg
# ✅ Annotata e salvata: staffe_171.jpg
# ✅ Annotata e salvata: staffe_172.jpg
# ✅ Annotata e salvata: staffe_173.jpg
# ✅ Annotata e salvata: staffe_174.jpg
# ✅ Annotata e salvata: staffe_175.jpg
# ✅ Annotata e salvata: staffe_176.jpg
# ✅ Annotata e salvata: staffe_177.jpg
# ✅ Annotata e salvata: staffe_178.png
# ✅ Annotata e salvata: staffe_179.jpg
# ✅ Annotata e salvata: staffe_180.jpg
# ✅ Annotata e salvata: staffe_181.jpg
# ✅ Annotata e salvata: staffe_182.jpg
# ✅ Annotata e salvata: staffe_183.jpg
# ✅ Annotata e salvata: staffe_184.jpg
# ✅ Annotata e salvata: staffe_185.png
# ✅ Annotata e salvata: staffe_186.jpg
# ✅ Annotata e salvata: staffe_187.jpg
# ✅ Annotata e salvata: staffe_188.jpg
# ✅ Annotata e salvata: staffe_189.jpg
# ✅ Annotata e salvata: staffe_190.jpg
# ✅ Annotata e salvata: staffe_191.jpg
# ✅ Annotata e salvata: staffe_192.png
# ✅ Annotata e salvata: staffe_193.jpg
# ✅ Annotata e salvata: staffe_194.jpg
# ✅ Annotata e salvata: staffe_195.jpg
# ✅ Annotata e salvata: staffe_196.jpg
# ✅ Annotata e salvata: staffe_197.jpg
# ✅ Annotata e salvata: staffe_198.png
# ✅ Annotata e salvata: staffe_199.jpg
# ✅ Annotata e salvata: staffe_200.jpg
# ✅ Annotata e salvata: staffe_201.jpg
# ✅ Annotata e salvata: staffe_202.jpg
# ✅ Annotata e salvata: staffe_203.jpg
# ✅ Annotata e salvata: staffe_204.jpg
# ✅ Annotata e salvata: staffe_205.jpg
# ✅ Annotata e salvata: staffe_206.jpg
# ✅ Annotata e salvata: staffe_207.jpg
# ✅ Annotata e salvata: staffe_208.jpg
# ✅ Annotata e salvata: staffe_209.jpg
# ✅ Annotata e salvata: staffe_210.jpg
# ✅ Annotata e salvata: staffe_211.png
# ✅ Annotata e salvata: staffe_212.jpg
# ✅ Annotata e salvata: staffe_213.jpg
# ✅ Annotata e salvata: staffe_214.jpg
# ✅ Annotata e salvata: staffe_215.jpg
# ✅ Annotata e salvata: staffe_216.jpg
# ✅ Annotata e salvata: staffe_217.jpg
# ✅ Annotata e salvata: staffe_218.jpg
# ✅ Annotata e salvata: staffe_219.jpg
# ✅ Annotata e salvata: staffe_220.jpg
# ✅ Annotata e salvata: staffe_221.jpg
# ✅ Annotata e salvata: staffe_222.jpg
# ✅ Annotata e salvata: staffe_223.jpg
# ✅ Annotata e salvata: staffe_224.png
# ✅ Annotata e salvata: staffe_225.jpg
# ✅ Annotata e salvata: staffe_226.png
# ✅ Annotata e salvata: staffe_227.png
# ✅ Annotata e salvata: staffe_228.png
# ✅ Annotata e salvata: staffe_229.png
# ✅ Annotata e salvata: staffe_230.jpg
# ✅ Annotata e salvata: staffe_231.png
# ✅ Annotata e salvata: staffe_232.jpg
# ✅ Annotata e salvata: staffe_233.png
# ✅ Annotata e salvata: staffe_234.png
# ✅ Annotata e salvata: staffe_235.jpg
# ✅ Annotata e salvata: staffe_236.png
# ✅ Annotata e salvata: staffe_237.png
# ✅ Annotata e salvata: staffe_238.png
# ✅ Annotata e salvata: staffe_239.png
# ✅ Annotata e salvata: staffe_240.jpg
# ✅ Annotata e salvata: staffe_241.png
# ✅ Annotata e salvata: staffe_242.jpg
# ✅ Annotata e salvata: staffe_243.png
# ✅ Annotata e salvata: staffe_244.jpg
# ✅ Annotata e salvata: staffe_245.jpg
# ✅ Annotata e salvata: staffe_246.jpg
# ✅ Annotata e salvata: staffe_247.png
# ✅ Annotata e salvata: staffe_248.jpg
# ✅ Annotata e salvata: staffe_249.jpg
# ✅ Annotata e salvata: staffe_250.jpg
# ✅ Annotata e salvata: staffe_251.png
# ✅ Annotata e salvata: staffe_252.jpg
# ✅ Annotata e salvata: staffe_253.png
# ✅ Annotata e salvata: staffe_254.png
# ✅ Annotata e salvata: staffe_255.jpg
# ✅ Annotata e salvata: staffe_256.jpg
# ✅ Annotata e salvata: staffe_257.jpg
# ✅ Annotata e salvata: staffe_258.jpg
#
# 📄 CSV salvato con successo: /content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_Nostri/Dataset_Clean_GoodAnnotation/output/numero_keypoints_log.csv
# ✅ Tutte le immagini elaborate.

# %% [markdown]
# # **TROVO NEL FILE .CSV IL NUMERO MASSIMO DI KEYPOINT**
# Perchè farlo? perchè così capisco quanti keypoints con flag "invisibile" mettere per ciascuna immagine annotata.

# %%
import csv

# === PERCORSO AL FILE CSV ===
csv_path = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_Nostri/Dataset_Clean_GoodAnnotation/output/numero_keypoints_log.csv"

max_kp = 0

with open(csv_path, newline='') as csvfile:
    reader = csv.DictReader(csvfile)

    for row in reader:
        for key, value in row.items():
            if key and key.startswith("num_kp_box") and value is not None and value.strip():
                try:
                    val = int(value)
                    if val > max_kp:
                        max_kp = val
                except ValueError:
                    continue  # in caso ci siano celle vuote o non numeriche

print(f" Numero max. di keypoints in una bounding box: {max_kp}")
# Out:
#  Numero max. di keypoints in una bounding box: 11

# %% [markdown]
# # **SISTEMAZIONE ANNOTAZIONE**
#
# 1) Analizza ogni bounding box (riga del file)
#
# 2) Conta i keypoints presenti (basato su triple x y v)
#
# 3) Se < 14 keypoints → aggiunge fittizi 0.0 0.0 0 fino a **15**
#
# 4) Salva i file corretti in una nuova cartella di output

# %% [markdown]
# ---

# %%
import os

input_dir = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_Nostri/Dataset_Clean_GoodAnnotation/labels"
output_dir = "/content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_Nostri/Dataset_Clean_GoodAnnotation/labels_corrette"
num_kp_target = 7  # numero di keypoints da raggiungere (fissi)

# === CREA CARTELLA DI OUTPUT ===
os.makedirs(output_dir, exist_ok=True)

# === PROCESSA OGNI FILE .TXT ===
for file_name in sorted(os.listdir(input_dir)):
    if not file_name.endswith('.txt'):
        continue

    input_path = os.path.join(input_dir, file_name)
    output_path = os.path.join(output_dir, file_name)

    with open(input_path, 'r') as f:
        lines = f.readlines()

    fixed_lines = []

    for line in lines:
        parts = line.strip().split()
        if len(parts) < 5:
            continue  # salta righe malformate!!!!!!!!!!

        # Estrai le parti
        class_id = parts[0]
        bbox = parts[1:5]
        keypoints = parts[5:]

        # Conta i keypoints reali (ogni keypoint ha 3 valori)
        kp_current = len(keypoints) // 3
        kp_missing = num_kp_target - kp_current

        # Aggiungi keypoints fittizi se mancano
        if kp_missing > 0:
            keypoints += ['0.0', '0.0', '0'] * kp_missing

        # Ricostruisci la riga
        fixed_line = " ".join([class_id] + bbox + keypoints)
        fixed_lines.append(fixed_line)

    # Scrivi il nuovo file
    with open(output_path, 'w') as f:
        for line in fixed_lines:
            f.write(line + "\n")

    print(f"✅ Fix completato: {file_name}")

print("\Tutti i file sono stati sistemati in:", output_dir)
# Out:
# ✅ Fix completato: staffe_001.txt
# ✅ Fix completato: staffe_002.txt
# ✅ Fix completato: staffe_003.txt
# ✅ Fix completato: staffe_004.txt
# ✅ Fix completato: staffe_005.txt
# ✅ Fix completato: staffe_006.txt
# ✅ Fix completato: staffe_007.txt
# ✅ Fix completato: staffe_008.txt
# ✅ Fix completato: staffe_009.txt
# ✅ Fix completato: staffe_010.txt
# ✅ Fix completato: staffe_011.txt
# ✅ Fix completato: staffe_012.txt
# ✅ Fix completato: staffe_013.txt
# ✅ Fix completato: staffe_014.txt
# ✅ Fix completato: staffe_015.txt
# ✅ Fix completato: staffe_016.txt
# ✅ Fix completato: staffe_017.txt
# ✅ Fix completato: staffe_018.txt
# ✅ Fix completato: staffe_019.txt
# ✅ Fix completato: staffe_020.txt
# ✅ Fix completato: staffe_021.txt
# ✅ Fix completato: staffe_022.txt
# ✅ Fix completato: staffe_025.txt
# ✅ Fix completato: staffe_026.txt
# ✅ Fix completato: staffe_027.txt
# ✅ Fix completato: staffe_028.txt
# ✅ Fix completato: staffe_029.txt
# ✅ Fix completato: staffe_030.txt
# ✅ Fix completato: staffe_031.txt
# ✅ Fix completato: staffe_037.txt
# ✅ Fix completato: staffe_038.txt
# ✅ Fix completato: staffe_039.txt
# ✅ Fix completato: staffe_040.txt
# ✅ Fix completato: staffe_041.txt
# ✅ Fix completato: staffe_042.txt
# ✅ Fix completato: staffe_043.txt
# ✅ Fix completato: staffe_044.txt
# ✅ Fix completato: staffe_046.txt
# ✅ Fix completato: staffe_047.txt
# ✅ Fix completato: staffe_049.txt
# ✅ Fix completato: staffe_050.txt
# ✅ Fix completato: staffe_051.txt
# ✅ Fix completato: staffe_052.txt
# ✅ Fix completato: staffe_053.txt
# ✅ Fix completato: staffe_054.txt
# ✅ Fix completato: staffe_055.txt
# ✅ Fix completato: staffe_056.txt
# ✅ Fix completato: staffe_057.txt
# ✅ Fix completato: staffe_058.txt
# ✅ Fix completato: staffe_059.txt
# ✅ Fix completato: staffe_060.txt
# ✅ Fix completato: staffe_061.txt
# ✅ Fix completato: staffe_062.txt
# ✅ Fix completato: staffe_063.txt
# ✅ Fix completato: staffe_064.txt
# ✅ Fix completato: staffe_065.txt
# ✅ Fix completato: staffe_066.txt
# ✅ Fix completato: staffe_068.txt
# ✅ Fix completato: staffe_069.txt
# ✅ Fix completato: staffe_071.txt
# ✅ Fix completato: staffe_072.txt
# ✅ Fix completato: staffe_073.txt
# ✅ Fix completato: staffe_074.txt
# ✅ Fix completato: staffe_075.txt
# ✅ Fix completato: staffe_076.txt
# ✅ Fix completato: staffe_077.txt
# ✅ Fix completato: staffe_078.txt
# ✅ Fix completato: staffe_079.txt
# ✅ Fix completato: staffe_080.txt
# ✅ Fix completato: staffe_081.txt
# ✅ Fix completato: staffe_082.txt
# ✅ Fix completato: staffe_083.txt
# ✅ Fix completato: staffe_084.txt
# ✅ Fix completato: staffe_085.txt
# ✅ Fix completato: staffe_086.txt
# ✅ Fix completato: staffe_087.txt
# ✅ Fix completato: staffe_088.txt
# ✅ Fix completato: staffe_089.txt
# ✅ Fix completato: staffe_090.txt
# ✅ Fix completato: staffe_091.txt
# ✅ Fix completato: staffe_092.txt
# ✅ Fix completato: staffe_093.txt
# ✅ Fix completato: staffe_094.txt
# ✅ Fix completato: staffe_096.txt
# ✅ Fix completato: staffe_097.txt
# ✅ Fix completato: staffe_098.txt
# ✅ Fix completato: staffe_099.txt
# ✅ Fix completato: staffe_100.txt
# ✅ Fix completato: staffe_101.txt
# ✅ Fix completato: staffe_102.txt
# ✅ Fix completato: staffe_103.txt
# ✅ Fix completato: staffe_104.txt
# ✅ Fix completato: staffe_105.txt
# ✅ Fix completato: staffe_106.txt
# ✅ Fix completato: staffe_107.txt
# ✅ Fix completato: staffe_108.txt
# ✅ Fix completato: staffe_109.txt
# ✅ Fix completato: staffe_110.txt
# ✅ Fix completato: staffe_111.txt
# ✅ Fix completato: staffe_112.txt
# ✅ Fix completato: staffe_113.txt
# ✅ Fix completato: staffe_114.txt
# ✅ Fix completato: staffe_115.txt
# ✅ Fix completato: staffe_116.txt
# ✅ Fix completato: staffe_117.txt
# ✅ Fix completato: staffe_118.txt
# ✅ Fix completato: staffe_119.txt
# ✅ Fix completato: staffe_120.txt
# ✅ Fix completato: staffe_121.txt
# ✅ Fix completato: staffe_122.txt
# ✅ Fix completato: staffe_123.txt
# ✅ Fix completato: staffe_124.txt
# ✅ Fix completato: staffe_125.txt
# ✅ Fix completato: staffe_126.txt
# ✅ Fix completato: staffe_127.txt
# ✅ Fix completato: staffe_128.txt
# ✅ Fix completato: staffe_129.txt
# ✅ Fix completato: staffe_130.txt
# ✅ Fix completato: staffe_131.txt
# ✅ Fix completato: staffe_132.txt
# ✅ Fix completato: staffe_133.txt
# ✅ Fix completato: staffe_134.txt
# ✅ Fix completato: staffe_135.txt
# ✅ Fix completato: staffe_136.txt
# ✅ Fix completato: staffe_137.txt
# ✅ Fix completato: staffe_138.txt
# ✅ Fix completato: staffe_139.txt
# ✅ Fix completato: staffe_140.txt
# ✅ Fix completato: staffe_141.txt
# ✅ Fix completato: staffe_142.txt
# ✅ Fix completato: staffe_143.txt
# ✅ Fix completato: staffe_144.txt
# ✅ Fix completato: staffe_145.txt
# ✅ Fix completato: staffe_146.txt
# ✅ Fix completato: staffe_147.txt
# ✅ Fix completato: staffe_148.txt
# ✅ Fix completato: staffe_149.txt
# ✅ Fix completato: staffe_150.txt
# ✅ Fix completato: staffe_151.txt
# ✅ Fix completato: staffe_152.txt
# ✅ Fix completato: staffe_153.txt
# ✅ Fix completato: staffe_154.txt
# ✅ Fix completato: staffe_155.txt
# ✅ Fix completato: staffe_156.txt
# ✅ Fix completato: staffe_157.txt
# ✅ Fix completato: staffe_158.txt
# ✅ Fix completato: staffe_159.txt
# ✅ Fix completato: staffe_160.txt
# ✅ Fix completato: staffe_161.txt
# ✅ Fix completato: staffe_162.txt
# ✅ Fix completato: staffe_163.txt
# ✅ Fix completato: staffe_164.txt
# ✅ Fix completato: staffe_165.txt
# ✅ Fix completato: staffe_168.txt
# ✅ Fix completato: staffe_169.txt
# ✅ Fix completato: staffe_170.txt
# ✅ Fix completato: staffe_171.txt
# ✅ Fix completato: staffe_172.txt
# ✅ Fix completato: staffe_173.txt
# ✅ Fix completato: staffe_174.txt
# ✅ Fix completato: staffe_175.txt
# ✅ Fix completato: staffe_176.txt
# ✅ Fix completato: staffe_177.txt
# ✅ Fix completato: staffe_178.txt
# ✅ Fix completato: staffe_179.txt
# ✅ Fix completato: staffe_180.txt
# ✅ Fix completato: staffe_181.txt
# ✅ Fix completato: staffe_182.txt
# ✅ Fix completato: staffe_183.txt
# ✅ Fix completato: staffe_184.txt
# ✅ Fix completato: staffe_185.txt
# ✅ Fix completato: staffe_186.txt
# ✅ Fix completato: staffe_187.txt
# ✅ Fix completato: staffe_188.txt
# ✅ Fix completato: staffe_189.txt
# ✅ Fix completato: staffe_190.txt
# ✅ Fix completato: staffe_191.txt
# ✅ Fix completato: staffe_192.txt
# ✅ Fix completato: staffe_193.txt
# ✅ Fix completato: staffe_194.txt
# ✅ Fix completato: staffe_195.txt
# ✅ Fix completato: staffe_196.txt
# ✅ Fix completato: staffe_197.txt
# ✅ Fix completato: staffe_198.txt
# ✅ Fix completato: staffe_199.txt
# ✅ Fix completato: staffe_200.txt
# ✅ Fix completato: staffe_201.txt
# ✅ Fix completato: staffe_202.txt
# ✅ Fix completato: staffe_203.txt
# ✅ Fix completato: staffe_204.txt
# ✅ Fix completato: staffe_205.txt
# ✅ Fix completato: staffe_206.txt
# ✅ Fix completato: staffe_207.txt
# ✅ Fix completato: staffe_208.txt
# ✅ Fix completato: staffe_209.txt
# ✅ Fix completato: staffe_210.txt
# ✅ Fix completato: staffe_211.txt
# ✅ Fix completato: staffe_212.txt
# ✅ Fix completato: staffe_213.txt
# ✅ Fix completato: staffe_214.txt
# ✅ Fix completato: staffe_215.txt
# ✅ Fix completato: staffe_216.txt
# ✅ Fix completato: staffe_217.txt
# ✅ Fix completato: staffe_218.txt
# ✅ Fix completato: staffe_219.txt
# ✅ Fix completato: staffe_220.txt
# ✅ Fix completato: staffe_221.txt
# ✅ Fix completato: staffe_222.txt
# ✅ Fix completato: staffe_223.txt
# ✅ Fix completato: staffe_224.txt
# ✅ Fix completato: staffe_225.txt
# ✅ Fix completato: staffe_226.txt
# ✅ Fix completato: staffe_227.txt
# ✅ Fix completato: staffe_228.txt
# ✅ Fix completato: staffe_229.txt
# ✅ Fix completato: staffe_230.txt
# ✅ Fix completato: staffe_231.txt
# ✅ Fix completato: staffe_232.txt
# ✅ Fix completato: staffe_233.txt
# ✅ Fix completato: staffe_234.txt
# ✅ Fix completato: staffe_235.txt
# ✅ Fix completato: staffe_236.txt
# ✅ Fix completato: staffe_237.txt
# ✅ Fix completato: staffe_238.txt
# ✅ Fix completato: staffe_239.txt
# ✅ Fix completato: staffe_240.txt
# ✅ Fix completato: staffe_241.txt
# ✅ Fix completato: staffe_242.txt
# ✅ Fix completato: staffe_243.txt
# ✅ Fix completato: staffe_244.txt
# ✅ Fix completato: staffe_245.txt
# ✅ Fix completato: staffe_246.txt
# ✅ Fix completato: staffe_247.txt
# ✅ Fix completato: staffe_248.txt
# ✅ Fix completato: staffe_249.txt
# ✅ Fix completato: staffe_250.txt
# ✅ Fix completato: staffe_251.txt
# ✅ Fix completato: staffe_252.txt
# ✅ Fix completato: staffe_253.txt
# ✅ Fix completato: staffe_254.txt
# ✅ Fix completato: staffe_255.txt
# ✅ Fix completato: staffe_256.txt
# ✅ Fix completato: staffe_257.txt
# ✅ Fix completato: staffe_258.txt
# \Tutti i file sono stati sistemati in: /content/drive/MyDrive/Computer_Vision_&_Deep_Learning/DATASET/Datasets_Nostri/Dataset_Clean_GoodAnnotation/labels_corrette
